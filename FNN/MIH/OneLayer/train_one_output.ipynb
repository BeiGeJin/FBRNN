# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from tqdm import tqdm
import pickle
import os

# %%
class SwinehartAbbottNetworkOneLayer(nn.Module):
    def __init__(self, input_size, init_gain, init_shift, init_weight):
        super(SwinehartAbbottNetworkOneLayer, self).__init__()
        self.input_size = input_size
        #self.gain = nn.Parameter(torch.tensor(init_gain, dtype=torch.float32))
        #self.shift = nn.Parameter(torch.tensor(init_shift, dtype=torch.float32))
        #self.weights = nn.Parameter(torch.tensor(init_weight, dtype=torch.float32))

        self.gain = torch.tensor(init_gain, requires_grad=True, dtype=torch.float32)
        self.shift = torch.tensor(init_shift, requires_grad=True, dtype=torch.float32)
        self.weights = torch.tensor(init_weight, requires_grad=True, dtype=torch.float32)

        self.activation_func = nn.Sigmoid()
        self.output_gain = torch.tensor(3, requires_grad=True, dtype=torch.float32) # 3
        self.output_shift = torch.tensor(1, requires_grad=True, dtype=torch.float32) # 1


    
    def normal_pdf(self, theta):
        return 1.5 * torch.exp(-(theta ** 2)/2) - 0.5
    

    def gaussian_rf(self, x):
        theta_is = torch.linspace(0, 2 * torch.pi, self.input_size).view(-1,1)
        return self.normal_pdf(x-theta_is) + self.normal_pdf(x-theta_is+2*torch.pi) + self.normal_pdf(x-theta_is-2*torch.pi)

    def forward(self, x):

        x = self.gaussian_rf(x)
        self.input_activations = x.clone()

        x = self.activation_func(self.gain * (x - self.shift))
        self.hidden_activations = x.clone()

        x = torch.matmul(self.weights, x)
        x = self.activation_func(self.output_gain * (x - self.output_shift))
        self.output_activations = x.clone()

        return x

# %% [markdown]
# ### Simulation

# %%
input_size = 230
hebb_alpha = int(input_size * 1) 

init_gain = 3 * np.ones((input_size, 1))
init_shift = 1 * np.ones((input_size, 1))
init_weight = np.ones((1, input_size)) 
init_weight /= np.sum(init_weight) 
init_weight *= hebb_alpha

torch.manual_seed(42)

# Data Generation, we will generate data points between 0 and 2*pi
ndata = 50
xs = torch.linspace(0, 2 * torch.pi, ndata)
ys = torch.cos(xs)/4 + 0.5

# training loop
num_epochs = 600
num_train_data = ndata*num_epochs 

controller_lr = 0.8 #0.2
hebbian_lr = 0.03

has_controller = True
has_hebbian = True


# establish model
model = SwinehartAbbottNetworkOneLayer(input_size, init_gain, init_shift, init_weight)
loss_func = nn.MSELoss()
optimizer = optim.SGD([model.gain, model.shift], lr=controller_lr)
#optimizer = optim.SGD([model.gain, model.shift, model.output_gain, model.output_shift], lr=controller_lr)


# Things to track
rc_losses = np.zeros(num_train_data+1)
#rc_outputs =  np.zeros(num_train_data)
rc_gains = np.zeros((input_size, num_train_data+1))
rc_shifts = np.zeros((input_size, num_train_data+1))
rc_weights = np.zeros((input_size, num_train_data+1))
rc_activations = np.zeros((input_size, num_train_data+1))


check_rf_every = 100
num_rc_rfs = int(np.ceil(num_train_data/check_rf_every))
rc_receptive_fields = np.zeros((input_size, ndata, num_rc_rfs))
rc_rfs_weights = np.zeros((input_size, num_rc_rfs))
rc_rfs_outputs = np.zeros((ndata, num_rc_rfs))



rc_gains[:, 0] = model.gain.detach().numpy().squeeze()
rc_shifts[:, 0] = model.shift.detach().numpy().squeeze()
rc_weights[:, 0] = model.weights.detach().numpy().squeeze()

# %%
rc_ind = 1
rc_rf_ind = 0
for epoch in range(num_epochs):

    # shuffle data
    perm_idx = np.arange(ndata) #torch.randperm(ndata)
    shuffled_xs = xs[perm_idx]
    shuffled_ys = ys[perm_idx]

    epoch_loss = 0

    # forward
    for x, y in zip(shuffled_xs, shuffled_ys):     

        # forward   
        actv_opl = model(x)
        output = actv_opl.squeeze()

        # Calculate loss
        loss = 0.5 * loss_func(output, y)
        epoch_loss += loss

        # backprop for gains and shifts
        if has_controller:

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()


        # hebbian learning for weights
        if has_hebbian:

            hebbian_update = model.output_activations * (model.hidden_activations).T
            with torch.no_grad():
                model.weights += hebbian_lr * hebbian_update
                model.weights /= torch.sum(model.weights) 
                model.weights *= hebb_alpha



        # Record responses
        rc_gains[:, rc_ind] = model.gain.detach().numpy().squeeze()
        rc_shifts[:, rc_ind] = model.shift.detach().numpy().squeeze()
        rc_weights[:, rc_ind] = model.weights.detach().numpy().squeeze()
        rc_activations[:, epoch+1] = model.input_activations.detach().numpy().squeeze()
        rc_losses[rc_ind] = epoch_loss.item()

        if rc_ind % check_rf_every == 0:
            with torch.no_grad():
                for i, x in enumerate(xs):
                    interm_outputs = model(x)
                    hidden_acts = model.hidden_activations.detach().numpy().squeeze()
                    rc_receptive_fields[:, i, rc_rf_ind] = hidden_acts
                rc_rfs_weights[:, rc_rf_ind] = model.weights.detach().numpy().squeeze()
                rc_rfs_outputs[:, rc_rf_ind] = model(xs).detach().numpy().squeeze()

                rc_rf_ind += 1
            
        rc_ind += 1


    # print losses
    epoch_loss /= ndata
    if (epoch + 1) % 10 == 0:
        gain_change = np.sum(np.abs(rc_gains[:, epoch] - rc_gains[:, epoch-1]))
        shift_change = np.sum(np.abs(rc_shifts[:, epoch] - rc_shifts[:, epoch-1]))
        weight_change = np.sum(np.abs(rc_weights[:, epoch] - rc_weights[:, epoch-1]))

        print(f"Epoch: {epoch}, Loss: {epoch_loss}, gain change: {gain_change}, shift change: {shift_change}, weight change: {weight_change}")
# Out:
# Epoch: 9, Loss: 4.9126938392873853e-05, gain change: 0.04079604148864746, shift change: 0.09815514087677002, weight change: 0.07734841108322144
# Epoch: 19, Loss: 6.944606411707355e-06, gain change: 0.0922701358795166, shift change: 0.22063350677490234, weight change: 0.07470524311065674
# Epoch: 29, Loss: 3.6217686556483386e-06, gain change: 0.12554001808166504, shift change: 0.2981584072113037, weight change: 0.07153379917144775
# Epoch: 39, Loss: 2.6468831038073404e-06, gain change: 0.07979249954223633, shift change: 0.1901329755783081, weight change: 0.07175511121749878
# Epoch: 49, Loss: 2.2715903469361365e-06, gain change: 0.034800052642822266, shift change: 0.08381462097167969, weight change: 0.07482177019119263
# Epoch: 59, Loss: 2.0802008293685503e-06, gain change: 0.06914782524108887, shift change: 0.16404294967651367, weight change: 0.06923484802246094
# Epoch: 69, Loss: 1.931058932314045e-06, gain change: 0.22902441024780273, shift change: 0.5262612104415894, weight change: 0.05756920576095581
# Epoch: 79, Loss: 1.7880072391562862e-06, gain change: 0.38099050521850586, shift change: 0.8457688093185425, weight change: 0.043572068214416504
# Epoch: 89, Loss: 1.6475315760544618e-06, gain change: 0.19503331184387207, shift change: 0.44296789169311523, weight change: 0.04770660400390625
# Epoch: 99, Loss: 1.5134563682295266e-06, gain change: 0.06576347351074219, shift change: 0.1559276580810547, weight change: 0.06125003099441528
# Epoch: 109, Loss: 1.3900222484153346e-06, gain change: 0.13269281387329102, shift change: 0.3073604106903076, weight change: 0.0527111291885376
# Epoch: 119, Loss: 1.2795644579455256e-06, gain change: 0.29185009002685547, shift change: 0.624334454536438, weight change: 0.025840342044830322
# Epoch: 129, Loss: 1.1814474873972358e-06, gain change: 0.2070150375366211, shift change: 0.4286903142929077, weight change: 0.016895830631256104
# Epoch: 139, Loss: 1.0945637995973811e-06, gain change: 0.1212623119354248, shift change: 0.26553213596343994, weight change: 0.029179275035858154
# Epoch: 149, Loss: 1.0175841680393205e-06, gain change: 0.058191537857055664, shift change: 0.13498973846435547, weight change: 0.04633063077926636
# Epoch: 159, Loss: 9.492251251685957e-07, gain change: 0.07940530776977539, shift change: 0.17713356018066406, weight change: 0.0332409143447876
# Epoch: 169, Loss: 8.873687988852907e-07, gain change: 0.08623695373535156, shift change: 0.17722272872924805, weight change: 0.013419926166534424
# Epoch: 179, Loss: 8.316619641846046e-07, gain change: 0.07126450538635254, shift change: 0.14366364479064941, weight change: 0.010272443294525146
# Epoch: 189, Loss: 7.806973485458002e-07, gain change: 0.029472827911376953, shift change: 0.06343436241149902, weight change: 0.021934032440185547
# Epoch: 199, Loss: 7.33523677354242e-07, gain change: 0.019382476806640625, shift change: 0.04433000087738037, weight change: 0.03890770673751831
# Epoch: 209, Loss: 6.892525448165543e-07, gain change: 0.016671180725097656, shift change: 0.03666555881500244, weight change: 0.027174830436706543
# Epoch: 219, Loss: 6.473730422840163e-07, gain change: 0.03855156898498535, shift change: 0.0782616138458252, weight change: 0.01082700490951538
# Epoch: 229, Loss: 6.076055001358327e-07, gain change: 0.038753509521484375, shift change: 0.07732963562011719, weight change: 0.008564472198486328
# Epoch: 239, Loss: 5.697870619769674e-07, gain change: 0.0021643638610839844, shift change: 0.004639744758605957, weight change: 0.02006244659423828
# Epoch: 249, Loss: 5.337090556167823e-07, gain change: 0.005579233169555664, shift change: 0.012719988822937012, weight change: 0.03701120615005493
# Epoch: 259, Loss: 4.992083404431469e-07, gain change: 0.0010592937469482422, shift change: 0.0023322105407714844, weight change: 0.0257452130317688
# Epoch: 269, Loss: 4.661590082832845e-07, gain change: 0.021297931671142578, shift change: 0.04298281669616699, weight change: 0.009811460971832275
# Epoch: 279, Loss: 4.3450918951748463e-07, gain change: 0.025756120681762695, shift change: 0.05108988285064697, weight change: 0.00781470537185669
# Epoch: 289, Loss: 4.041862382564432e-07, gain change: 0.004336357116699219, shift change: 0.009289026260375977, weight change: 0.01965254545211792
# Epoch: 299, Loss: 3.7537236607931845e-07, gain change: 0.003481149673461914, shift change: 0.007932662963867188, weight change: 0.036641478538513184
# Epoch: 309, Loss: 3.4780583746396587e-07, gain change: 0.004821300506591797, shift change: 0.010576248168945312, weight change: 0.02544766664505005
# Epoch: 319, Loss: 3.21570951200556e-07, gain change: 0.01282191276550293, shift change: 0.025786280632019043, weight change: 0.009303808212280273
# Epoch: 329, Loss: 2.9671716106349777e-07, gain change: 0.018703460693359375, shift change: 0.036956071853637695, weight change: 0.007376253604888916
# Epoch: 339, Loss: 2.7319640594214434e-07, gain change: 0.005587577819824219, shift change: 0.011972904205322266, weight change: 0.01957756280899048
# Epoch: 349, Loss: 2.5098171363424626e-07, gain change: 0.0037496089935302734, shift change: 0.00854647159576416, weight change: 0.036518752574920654
# Epoch: 359, Loss: 2.3016654893126542e-07, gain change: 0.004586219787597656, shift change: 0.010065674781799316, weight change: 0.025468289852142334
# Epoch: 369, Loss: 2.1079038958760066e-07, gain change: 0.007912158966064453, shift change: 0.015877604484558105, weight change: 0.009000957012176514
# Epoch: 379, Loss: 1.9280182073089236e-07, gain change: 0.014238834381103516, shift change: 0.02805030345916748, weight change: 0.0070934295654296875
# Epoch: 389, Loss: 1.7605290736355528e-07, gain change: 0.005437612533569336, shift change: 0.011658668518066406, weight change: 0.019619524478912354
# Epoch: 399, Loss: 1.6059648544342053e-07, gain change: 0.0040395259857177734, shift change: 0.009197235107421875, weight change: 0.036402225494384766
# Epoch: 409, Loss: 1.4631294220635027e-07, gain change: 0.0033135414123535156, shift change: 0.00727689266204834, weight change: 0.02556777000427246
# Epoch: 419, Loss: 1.3321046310466045e-07, gain change: 0.004781007766723633, shift change: 0.009582877159118652, weight change: 0.008809328079223633
# Epoch: 429, Loss: 1.2118154302243056e-07, gain change: 0.011157989501953125, shift change: 0.0219343900680542, weight change: 0.006899535655975342
# Epoch: 439, Loss: 1.101925661828318e-07, gain change: 0.0048558712005615234, shift change: 0.010420680046081543, weight change: 0.019661545753479004
# Epoch: 449, Loss: 1.0024307783851327e-07, gain change: 0.00400233268737793, shift change: 0.009111523628234863, weight change: 0.03622281551361084
# Epoch: 459, Loss: 9.121831112679502e-08, gain change: 0.0019152164459228516, shift change: 0.004211902618408203, weight change: 0.025664031505584717
# Epoch: 469, Loss: 8.302861687070617e-08, gain change: 0.0026602745056152344, shift change: 0.0053288936614990234, weight change: 0.008697211742401123
# Epoch: 479, Loss: 7.561897064078948e-08, gain change: 0.00891566276550293, shift change: 0.017501235008239746, weight change: 0.006762504577636719
# Epoch: 489, Loss: 6.894980231209047e-08, gain change: 0.0041255950927734375, shift change: 0.008859395980834961, weight change: 0.019728779792785645
# Epoch: 499, Loss: 6.296979648823253e-08, gain change: 0.0037279129028320312, shift change: 0.008482933044433594, weight change: 0.0360296368598938
# Epoch: 509, Loss: 5.7571259759470195e-08, gain change: 0.0006728172302246094, shift change: 0.0014765262603759766, weight change: 0.025727272033691406
# Epoch: 519, Loss: 5.27394874438869e-08, gain change: 0.001165151596069336, shift change: 0.0023283958435058594, weight change: 0.008625686168670654
# Epoch: 529, Loss: 4.8405986774469056e-08, gain change: 0.007222652435302734, shift change: 0.014156818389892578, weight change: 0.0066599249839782715
# Epoch: 539, Loss: 4.453455915154336e-08, gain change: 0.003353595733642578, shift change: 0.0072051286697387695, weight change: 0.01978135108947754
# Epoch: 549, Loss: 4.1091922753366816e-08, gain change: 0.003340482711791992, shift change: 0.007586479187011719, weight change: 0.03582650423049927
# Epoch: 559, Loss: 3.799953063321482e-08, gain change: 0.0003559589385986328, shift change: 0.0007888078689575195, weight change: 0.025786936283111572
# Epoch: 569, Loss: 3.5266303655134834e-08, gain change: 6.866455078125e-05, shift change: 0.0001468658447265625, weight change: 0.008558034896850586
# Epoch: 579, Loss: 3.2795036020161206e-08, gain change: 0.005902528762817383, shift change: 0.011558771133422852, weight change: 0.006579220294952393
# Epoch: 589, Loss: 3.0608820367206135e-08, gain change: 0.0025980472564697266, shift change: 0.005585193634033203, weight change: 0.019851982593536377
# Epoch: 599, Loss: 2.862965686745156e-08, gain change: 0.0029153823852539062, shift change: 0.00662386417388916, weight change: 0.035628318786621094

# %% [markdown]
# ### Results

# %%
import matplotlib.pyplot as plt

# %%
#  set time points to check values
early_ind = int(num_rc_rfs*0.01)
mid_ind = int(num_rc_rfs*0.15)
late_ind = int(num_rc_rfs*0.95)

# randomly sample the units
num_units_sample = 20
samp_inds = np.linspace(0, input_size-1, num_units_sample).astype(int)

# EARLY TRAINING ---------------------

plt.figure(figsize=(14, 6))
plt.subplot(4,3,1)
vals = rc_receptive_fields[samp_inds, :, early_ind].T
plt.plot(vals);
#plt.ylim([0, 0.06])
plt.ylabel("Early")
plt.title("Input Firing Rates")

plt.subplot(4,3,2)
plt.plot(rc_rfs_weights[:,early_ind]);
plt.ylim([0, 1])
plt.title("Weights")

plt.subplot(4,3,3)
plt.plot(xs, ys, label="Target")
plt.plot(xs, rc_rfs_outputs[:,early_ind], '.',label="Model")
plt.title("Function Approximation")
plt.ylim([0, 1])
plt.legend()
 
# MID TRAINING ---------------------

plt.subplot(4,3,4)
vals = rc_receptive_fields[samp_inds, :, mid_ind].T
plt.plot(vals);
#plt.ylim([0, 0.06])
plt.ylabel("Mid")

plt.subplot(4,3,5)
plt.plot(rc_rfs_weights[:,mid_ind]);
plt.ylim([0, 1])

plt.subplot(4,3,6)
plt.plot(xs, ys, label="Target")
plt.plot(xs, rc_rfs_outputs[:,mid_ind], '.',label="Model")
plt.ylim([0, 1])
plt.legend()

# LATE TRAINING ---------------------

plt.subplot(4,3,7)
vals = rc_receptive_fields[samp_inds, :, late_ind].T
plt.plot(vals);
#plt.ylim([0, 0.06])
plt.ylabel("Late")

plt.subplot(4,3,8)
plt.plot(rc_rfs_weights[:,late_ind]);
plt.ylim([0, 1])

plt.subplot(4,3,9)
plt.plot(xs, ys, label="Target")
plt.plot(xs, rc_rfs_outputs[:,late_ind], '.',label="Model")
plt.ylim([0, 1])
plt.legend()



# POST TRAINING ---------------------
final_weights = model.weights.detach().numpy().squeeze()
new_model = SwinehartAbbottNetworkOneLayer(input_size, init_gain, init_shift, final_weights)
final_outputs = new_model(xs).detach().numpy().squeeze()
final_rfs = np.zeros((input_size, ndata))

for i, x in enumerate(xs):
    interm_outputs = new_model(x)
    final_rfs[:, i] = new_model.hidden_activations.detach().numpy().squeeze()


plt.subplot(4,3,10)
vals = final_rfs[samp_inds, :].T
plt.plot(vals);
#plt.ylim([0, 0.06])
plt.ylabel("Final")

plt.subplot(4,3,11)
plt.plot(final_weights);
plt.ylim([0, 1])

plt.subplot(4,3,12)
plt.plot(xs, ys, label="Target")
plt.plot(xs, final_outputs, '.',label="Model")
plt.ylim([0, 1])
plt.legend()

# %%
ex_unit = 150

plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.plot(rc_gains[ex_unit,:])
plt.title("Example unit gain during training")
plt.xlabel("Time")

plt.subplot(1,2,2)
plt.plot(rc_shifts[ex_unit,:], color="orange")
plt.title("Example unit shift during training")
plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
plt.figure()
plt.plot(model.gain.detach().numpy().squeeze())
plt.title("Final gain per unit")

plt.figure()
plt.plot(model.shift.detach().numpy().squeeze())
plt.title("Final shift per unit")
# Out:
# Text(0.5, 1.0, 'Final shift per unit')

# %% [markdown]
# ### Param Sweep

# %%
# Adjustable Params
input_size = 230

num_epochs = 600
controller_lr = 0.8 #0.2
hebbian_lr = 0.03

has_controller = True
has_hebbian = True


# Data Generation, we will generate data points between 0 and 2*pi
ndata = 50
xs = torch.linspace(0, 2 * torch.pi, ndata)
ys = torch.cos(xs)/4 + 0.5
torch.manual_seed(42)


# Things to track
num_gains = num_shifts = 10
all_gains = np.linspace(0, 10, num_gains)
all_shifts = np.linspace(-2, 10, num_shifts)
all_alpha_fracs = [0.1, 0.4, 0.8]
num_alphas = 3
all_losses = np.zeros((num_gains, num_shifts, num_alphas))
all_weights =  np.zeros((num_gains, num_shifts, num_alphas, input_size))
tracker = 0


# Run simulation
for a_ind, a_init in enumerate(all_alpha_fracs):
    for g_ind, g_init in enumerate(all_gains):
        for s_ind, s_init in enumerate(all_shifts):

            init_gain = g_init * np.ones((input_size, 1))
            init_shift = s_init * np.ones((input_size, 1))
            hebb_alpha = int(input_size * a_init) 

            init_weight = np.ones((1, input_size)) 
            init_weight /= np.sum(init_weight) 
            init_weight *= hebb_alpha

            model = SwinehartAbbottNetworkOneLayer(input_size, init_gain, init_shift, init_weight)
            loss_func = nn.MSELoss()
            optimizer = optim.SGD([model.gain, model.shift], lr=controller_lr)



            for epoch in range(num_epochs):

                # shuffle data
                perm_idx = np.arange(ndata) #torch.randperm(ndata)
                shuffled_xs = xs[perm_idx]
                shuffled_ys = ys[perm_idx]

                epoch_loss = 0

                # forward
                for x, y in zip(shuffled_xs, shuffled_ys):     

                    # forward   
                    actv_opl = model(x)
                    output = actv_opl.squeeze()

                    # Calculate loss
                    loss = 0.5 * loss_func(output, y)
                    epoch_loss += loss

                    # backprop for gains and shifts
                    if has_controller:

                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()


                    # hebbian learning for weights
                    if has_hebbian:

                        hebbian_update = model.output_activations * (model.hidden_activations).T
                        with torch.no_grad():
                            model.weights += hebbian_lr * hebbian_update
                            model.weights /= torch.sum(model.weights) 
                            model.weights *= hebb_alpha


                epoch_loss /= ndata
            
            all_losses[g_ind, s_ind, a_ind] = epoch_loss
            all_weights[g_ind, s_ind, a_ind, :] = model.weights.detach().numpy().squeeze()
            tracker+=1
            print(f"Done with {tracker} of {num_gains*num_shifts*3} simulations. Alpha: {a_init}, Gain: {g_init}, Shift: {s_init}, Final Loss: {epoch_loss}")
# Out:
# Done with 1 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 2 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 3 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 4 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 2.0, Final Loss: 0.13843750953674316
# Done with 5 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 3.333333333333333, Final Loss: 0.13843750953674316
# Done with 6 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 4.666666666666666, Final Loss: 0.13843750953674316
# Done with 7 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 6.0, Final Loss: 0.13843750953674316
# Done with 8 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 7.333333333333332, Final Loss: 0.13843750953674316
# Done with 9 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 8.666666666666666, Final Loss: 0.13843750953674316
# Done with 10 of 300 simulations. Alpha: 0.1, Gain: 0.0, Shift: 10.0, Final Loss: 0.13843750953674316
# Done with 11 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 12 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 13 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 0.6666666666666665, Final Loss: 4.479731614992488e-06
# Done with 14 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 2.0, Final Loss: 1.4986646419856697e-05
# Done with 15 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 3.333333333333333, Final Loss: 9.712720202514902e-05
# Done with 16 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 4.666666666666666, Final Loss: 0.00042249253601767123
# Done with 17 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 6.0, Final Loss: 0.0005296660820022225
# Done with 18 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 7.333333333333332, Final Loss: 9.132237028097734e-05
# Done with 19 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 8.666666666666666, Final Loss: 0.12054500728845596
# Done with 20 of 300 simulations. Alpha: 0.1, Gain: 1.1111111111111112, Shift: 10.0, Final Loss: 0.12060149013996124
# Done with 21 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 22 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 23 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 0.6666666666666665, Final Loss: 5.249278274277458e-07
# Done with 24 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 2.0, Final Loss: 7.453636499121785e-05
# Done with 25 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 3.333333333333333, Final Loss: 0.12014894187450409
# Done with 26 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 4.666666666666666, Final Loss: 0.1205996423959732
# Done with 27 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 6.0, Final Loss: 0.12061142176389694
# Done with 28 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 7.333333333333332, Final Loss: 0.12061203271150589
# Done with 29 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 30 of 300 simulations. Alpha: 0.1, Gain: 2.2222222222222223, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 31 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 32 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 33 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 0.6666666666666665, Final Loss: 7.283830427695648e-07
# Done with 34 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 2.0, Final Loss: 0.1189105436205864
# Done with 35 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 3.333333333333333, Final Loss: 0.12060772627592087
# Done with 36 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 4.666666666666666, Final Loss: 0.1206120029091835
# Done with 37 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 38 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 39 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 40 of 300 simulations. Alpha: 0.1, Gain: 3.3333333333333335, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 41 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 42 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 43 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 0.6666666666666665, Final Loss: 2.3630534542462556e-06
# Done with 44 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 2.0, Final Loss: 0.12057575583457947
# Done with 45 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 3.333333333333333, Final Loss: 0.12061193585395813
# Done with 46 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 47 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 48 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 49 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 50 of 300 simulations. Alpha: 0.1, Gain: 4.444444444444445, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 51 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 52 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 53 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 0.6666666666666665, Final Loss: 5.410420271800831e-06
# Done with 54 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 2.0, Final Loss: 0.12060891091823578
# Done with 55 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 56 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 57 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 58 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 59 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 60 of 300 simulations. Alpha: 0.1, Gain: 5.555555555555555, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 61 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 62 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 63 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 0.6666666666666665, Final Loss: 0.00017600279534235597
# Done with 64 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 2.0, Final Loss: 0.12061173468828201
# Done with 65 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 66 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 67 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 68 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 69 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 70 of 300 simulations. Alpha: 0.1, Gain: 6.666666666666667, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 71 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 72 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 73 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 0.6666666666666665, Final Loss: 0.0004467834660317749
# Done with 74 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 2.0, Final Loss: 0.12061203271150589
# Done with 75 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 76 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 77 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 78 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 79 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 80 of 300 simulations. Alpha: 0.1, Gain: 7.777777777777779, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 81 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 82 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 83 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 84 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 2.0, Final Loss: 0.12061205506324768
# Done with 85 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 86 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 87 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 88 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 89 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 90 of 300 simulations. Alpha: 0.1, Gain: 8.88888888888889, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 91 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 92 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 93 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 0.6666666666666665, Final Loss: 0.045028019696474075
# Done with 94 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 2.0, Final Loss: 0.12061205506324768
# Done with 95 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 96 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 97 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 98 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 99 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 100 of 300 simulations. Alpha: 0.1, Gain: 10.0, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 101 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 102 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 103 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 104 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 2.0, Final Loss: 0.13843750953674316
# Done with 105 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 3.333333333333333, Final Loss: 0.13843750953674316
# Done with 106 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 4.666666666666666, Final Loss: 0.13843750953674316
# Done with 107 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 6.0, Final Loss: 0.13843750953674316
# Done with 108 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 7.333333333333332, Final Loss: 0.13843750953674316
# Done with 109 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 8.666666666666666, Final Loss: 0.13843750953674316
# Done with 110 of 300 simulations. Alpha: 0.4, Gain: 0.0, Shift: 10.0, Final Loss: 0.13843750953674316
# Done with 111 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 112 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 113 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 114 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 2.0, Final Loss: 4.046552533054637e-07
# Done with 115 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 3.333333333333333, Final Loss: 3.328489810883184e-06
# Done with 116 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 4.666666666666666, Final Loss: 2.728944855334703e-05
# Done with 117 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 6.0, Final Loss: 0.00011288454697933048
# Done with 118 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 7.333333333333332, Final Loss: 9.758101077750325e-05
# Done with 119 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 8.666666666666666, Final Loss: 4.532978346105665e-05
# Done with 120 of 300 simulations. Alpha: 0.4, Gain: 1.1111111111111112, Shift: 10.0, Final Loss: 0.1205427348613739
# Done with 121 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 122 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 123 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 0.6666666666666665, Final Loss: 0.13842721283435822
# Done with 124 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 2.0, Final Loss: 4.8223807169733846e-08
# Done with 125 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 3.333333333333333, Final Loss: 0.0004279830609448254
# Done with 126 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 4.666666666666666, Final Loss: 0.12055505812168121
# Done with 127 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 6.0, Final Loss: 0.12060955166816711
# Done with 128 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 7.333333333333332, Final Loss: 0.12061191350221634
# Done with 129 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 130 of 300 simulations. Alpha: 0.4, Gain: 2.2222222222222223, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 131 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 132 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 133 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 0.6666666666666665, Final Loss: 6.570549437867612e-09
# Done with 134 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 2.0, Final Loss: 0.003354710526764393
# Done with 135 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 3.333333333333333, Final Loss: 0.12059412151575089
# Done with 136 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 4.666666666666666, Final Loss: 0.12061186134815216
# Done with 137 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 138 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 139 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 140 of 300 simulations. Alpha: 0.4, Gain: 3.3333333333333335, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 141 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 142 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 143 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 0.6666666666666665, Final Loss: 7.105483756930653e-09
# Done with 144 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 2.0, Final Loss: 0.12039316445589066
# Done with 145 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 3.333333333333333, Final Loss: 0.12061168998479843
# Done with 146 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 147 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 148 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 149 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 150 of 300 simulations. Alpha: 0.4, Gain: 4.444444444444445, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 151 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 152 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 153 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 0.6666666666666665, Final Loss: 9.328508632222565e-09
# Done with 154 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 2.0, Final Loss: 0.12059886753559113
# Done with 155 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 156 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 157 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 158 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 159 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 160 of 300 simulations. Alpha: 0.4, Gain: 5.555555555555555, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 161 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 162 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 163 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 0.6666666666666665, Final Loss: 1.2900176926677887e-08
# Done with 164 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 2.0, Final Loss: 0.12061081826686859
# Done with 165 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 166 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 167 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 168 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 169 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 170 of 300 simulations. Alpha: 0.4, Gain: 6.666666666666667, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 171 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 172 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 173 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 0.6666666666666665, Final Loss: 2.5438866941840388e-06
# Done with 174 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 2.0, Final Loss: 0.12061191350221634
# Done with 175 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 176 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 177 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 178 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 179 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 180 of 300 simulations. Alpha: 0.4, Gain: 7.777777777777779, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 181 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 182 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 183 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 0.6666666666666665, Final Loss: 0.00835040956735611
# Done with 184 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 2.0, Final Loss: 0.12061205506324768
# Done with 185 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 186 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 187 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 188 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 189 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 190 of 300 simulations. Alpha: 0.4, Gain: 8.88888888888889, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 191 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 192 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 193 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 194 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 2.0, Final Loss: 0.12061205506324768
# Done with 195 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 196 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 197 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 198 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 199 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 200 of 300 simulations. Alpha: 0.4, Gain: 10.0, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 201 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 202 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 203 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 204 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 2.0, Final Loss: 0.13843750953674316
# Done with 205 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 3.333333333333333, Final Loss: 0.13843750953674316
# Done with 206 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 4.666666666666666, Final Loss: 0.13843750953674316
# Done with 207 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 6.0, Final Loss: 0.13843750953674316
# Done with 208 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 7.333333333333332, Final Loss: 0.13843750953674316
# Done with 209 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 8.666666666666666, Final Loss: 0.13843750953674316
# Done with 210 of 300 simulations. Alpha: 0.8, Gain: 0.0, Shift: 10.0, Final Loss: 0.13843750953674316
# Done with 211 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 212 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 213 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 214 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 2.0, Final Loss: 0.13843750953674316
# Done with 215 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 3.333333333333333, Final Loss: 1.7772748606148525e-06
# Done with 216 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 4.666666666666666, Final Loss: 4.650191385735525e-06
# Done with 217 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 6.0, Final Loss: 4.275298124412075e-05
# Done with 218 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 7.333333333333332, Final Loss: 0.00018496379198040813
# Done with 219 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 8.666666666666666, Final Loss: 6.0969476180616766e-05
# Done with 220 of 300 simulations. Alpha: 0.8, Gain: 1.1111111111111112, Shift: 10.0, Final Loss: 0.00028432317776605487
# Done with 221 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 222 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 223 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 0.6666666666666665, Final Loss: 0.13843750953674316
# Done with 224 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 2.0, Final Loss: 6.510776984214317e-08
# Done with 225 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 3.333333333333333, Final Loss: 0.0038800931069999933
# Done with 226 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 4.666666666666666, Final Loss: 0.12046939134597778
# Done with 227 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 6.0, Final Loss: 0.12060703337192535
# Done with 228 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 7.333333333333332, Final Loss: 0.12061179429292679
# Done with 229 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 8.666666666666666, Final Loss: 0.12061204016208649
# Done with 230 of 300 simulations. Alpha: 0.8, Gain: 2.2222222222222223, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 231 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 232 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 233 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 0.6666666666666665, Final Loss: 4.829481703438887e-09
# Done with 234 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 2.0, Final Loss: 0.0061757550574839115
# Done with 235 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 3.333333333333333, Final Loss: 0.12057436257600784
# Done with 236 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 4.666666666666666, Final Loss: 0.12061163783073425
# Done with 237 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 238 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 239 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 240 of 300 simulations. Alpha: 0.8, Gain: 3.3333333333333335, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 241 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 242 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 243 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 0.6666666666666665, Final Loss: 3.507442336569966e-09
# Done with 244 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 2.0, Final Loss: 0.013385857455432415
# Done with 245 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 3.333333333333333, Final Loss: 0.12061133235692978
# Done with 246 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 247 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 248 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 249 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 250 of 300 simulations. Alpha: 0.8, Gain: 4.444444444444445, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 251 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 252 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 253 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 0.6666666666666665, Final Loss: 2.28743668451159e-09
# Done with 254 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 2.0, Final Loss: 0.12058410793542862
# Done with 255 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 3.333333333333333, Final Loss: 0.12061204016208649
# Done with 256 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 257 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 258 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 259 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 260 of 300 simulations. Alpha: 0.8, Gain: 5.555555555555555, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 261 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 262 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 263 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 0.6666666666666665, Final Loss: 2.887575512033891e-09
# Done with 264 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 2.0, Final Loss: 0.12060955911874771
# Done with 265 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 266 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 267 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 268 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 269 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 270 of 300 simulations. Alpha: 0.8, Gain: 6.666666666666667, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 271 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 272 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 273 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 0.6666666666666665, Final Loss: 1.8659134237708486e-09
# Done with 274 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 2.0, Final Loss: 0.12061180919408798
# Done with 275 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 276 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 277 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 278 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 279 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 280 of 300 simulations. Alpha: 0.8, Gain: 7.777777777777779, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 281 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 282 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 283 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 0.6666666666666665, Final Loss: 7.19500235391024e-07
# Done with 284 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 2.0, Final Loss: 0.12061203271150589
# Done with 285 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 286 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 287 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 288 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 289 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 290 of 300 simulations. Alpha: 0.8, Gain: 8.88888888888889, Shift: 10.0, Final Loss: 0.12061205506324768
# Done with 291 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: -2.0, Final Loss: 0.13843750953674316
# Done with 292 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: -0.6666666666666667, Final Loss: 0.13843750953674316
# Done with 293 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 0.6666666666666665, Final Loss: 1.7258701063838089e-06
# Done with 294 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 2.0, Final Loss: 0.12061205506324768
# Done with 295 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 3.333333333333333, Final Loss: 0.12061205506324768
# Done with 296 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 4.666666666666666, Final Loss: 0.12061205506324768
# Done with 297 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 6.0, Final Loss: 0.12061205506324768
# Done with 298 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 7.333333333333332, Final Loss: 0.12061205506324768
# Done with 299 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 8.666666666666666, Final Loss: 0.12061205506324768
# Done with 300 of 300 simulations. Alpha: 0.8, Gain: 10.0, Shift: 10.0, Final Loss: 0.12061205506324768

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming matrix, xvals, and yvals are already defined
plt.figure(figsize=(17, 5))

alphaInd = 0 
plt.subplot(1,3,1)
heatmap = sns.heatmap(all_losses[:,:,alphaInd].T, xticklabels=np.round(all_gains, 2), yticklabels=np.round(all_shifts, 2), cmap='viridis')
plt.xlabel('Init Gain Values')
plt.ylabel('Init Shift Values')
plt.title(f'Init Param Sweep (Alpha={input_size*all_alpha_fracs[alphaInd]})')
cbar = heatmap.collections[0].colorbar
cbar.set_label('Loss')
#plt.show()


alphaInd = 1 
plt.subplot(1,3,2)
heatmap = sns.heatmap(all_losses[:,:,alphaInd].T, xticklabels=np.round(all_gains, 2), yticklabels=np.round(all_shifts, 2), cmap='viridis')
plt.xlabel('Init Gain Values')
plt.ylabel('Init Shift Values')
plt.title(f'Init Param Sweep (Alpha={input_size*all_alpha_fracs[alphaInd]})')
cbar = heatmap.collections[0].colorbar
cbar.set_label('Loss')
#plt.show()


alphaInd = 2 
plt.subplot(1,3,3)
heatmap = sns.heatmap(all_losses[:,:,alphaInd].T, xticklabels=np.round(all_gains, 2), yticklabels=np.round(all_shifts, 2), cmap='viridis')
plt.xlabel('Init Gain Values')
plt.ylabel('Init Shift Values')
plt.title(f'Init Param Sweep (Alpha={input_size*all_alpha_fracs[alphaInd]})')
cbar = heatmap.collections[0].colorbar
cbar.set_label('Loss')
#plt.show()

# %%
all_losses[6, 2], all_gains[6], all_shifts[2]
# Out:
# (0.0033010286279022694, 6.666666666666667, 0.6666666666666665)
